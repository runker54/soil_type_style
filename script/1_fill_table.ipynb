# %%
import os
import pandas as pd

# %%
table_path = r"C:\Users\Runker\Desktop\贵州省第三次全国土壤普查土壤分类系统分类系统（试行版）-20251031修订版.xls"

# %%
df = pd.read_excel(table_path)

# %%
# 向前填充缺失值
df.fillna(method='ffill', inplace=True)
df.to_excel(r'D:\worker_code\color_table\table\新分类系统.xlsx', index=False)
